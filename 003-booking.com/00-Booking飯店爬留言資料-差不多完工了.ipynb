# %% [raw]
# !conda install urllib3

# %%
import requests
from bs4 import BeautifulSoup
#import lxml
#import urllib
#import re

# %%
# 這個網頁必須是這樣 以下兩個個網址在此不能用(是給web browser用的!!)
web = "http://www.booking.com/hotel/tw/richardson.zh-tw.html?aid=304142;label=gen173nr-1FEghlcnJvcjQwNCiCAkICWFhIM2IFbm9yZWZo5wGIAQGYATC4AQbIAQzYAQHoAQH4AQuoAgM;sid=90b9c00bb8c3b7852742d43f6165a9c4;dcid=12;checkin=2016-03-28;checkout=2016-03-29;dest_id=-2637882;dest_type=city;dist=0;highlighted_blocks=132412401_85683812_0_0;room1=A%2CA;sb_price_type=total;srfid=e4cc12616d37bc46a3986294c48e495e1250c468X1;type=total;ucfs=1&lang=zh-tw#tab-reviews"

# %% [raw]
# # 以下兩個個網址是給web browser用的!!
#
# # 這是從F12 Network XHR Header中 得到的 網址
# web = "https://www.booking.com/reviewlist.zh-tw.html?aid=304142;label=gen173nr-1FEghlcnJvcjQwNCiCAkICWFhIM2IFbm9yZWZo5wGIAQGYATC4AQbIAQzYAQHoAQH4AQuoAgM;sid=5359d7edc03f473e1747b8b55f54f8fb;cc1=tw;dist=1;pagename=richardson;r_lang=zh;roomtype=-1;type=total&;offset=20;rows=10&_=1516903624235"

# %% [raw]
# # 這是從selenium IDE中 按下下一頁按鈕 得到的 網址
# web = "https://www.booking.com/reviewlist.zh-tw.html?aid=304142;label=gen173nr-1FEghlcnJvcjQwNCiCAkICWFhIM2IFbm9yZWZo5wGIAQGYATC4AQbIAQzYAQHoAQH4AQuoAgM;sid=5359d7edc03f473e1747b8b55f54f8fb;cc1=tw;dist=1;pagename=richardson;r_lang=zh;roomtype=-1;type=total&;offset=0;rows=10"

# %%
res = requests.get(web)
#print res.text

# %%
res
# Out:
# <Response [200]>

# %% [raw]
# res.text

# %%
soup = BeautifulSoup(res.text.encode("utf-8"),'lxml')

# %%
# soup.prettify()

# %%
soup.find('div',{'class':'review_item_review_content'})
# Out:
# <div class="review_item_review_content">
# <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點方便，衞生</p>
# <p class="review_staydate ">
# 2018 年 3 月入住：
# </p>
# </div>

# %%
soup.findAll('div',{'class':'review_item_review_content'})
# Out:
# [<div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點方便，衞生</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音差，正巧遇到地震，但飯店廣播系統反應太慢。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通方便</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點超方便!</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晚上水渠常常發出水聲，及其他雜聲…</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通便利</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>服務人員可能因忙碌忽略微笑關係，表情比較嚴肅。另房間桌燈座下方電線蓋子未蓋妥。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間及浴室都很乾淨，住宿地點很便利！早餐多元化，非常美味！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>浴室門口記得做止水條,不然水會流出來哦</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>早餐豐富,不錯</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晩上聽到別的房間人搬東西的東西！太嘈！隔音不是很好！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>地氈有污積。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點非常近西門捷運站，入住及退房不同樓層，方便辦理入住及退房。並提供到足夠空間寄存行李。</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音設備好差！ 好嘈！</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>Location </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>食物一般，款式太少</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>沒有</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>物超所值，隔音也不錯，強烈推薦</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>空調無法調自己想要的溫度，調完後還是會回到19度，很冷</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>空間舒適</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>沒有免費的停車場</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點佳，價錢適中
#  房間雖然不是很大，但還算舒適
#  員工有貼心備註並提供需求</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音非常差每次有人經過房間都聽到對話或附近出入的開關房門聲非常嘈吵完全影響睡眠空調亦不準確與預設的溫度差距10幾度房務員亦非常粗魯製造大量噪音</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>職員給予要求的高樓層</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>有對外窗戶但沒有遮光窗簾 霓虹燈亮 怕光的人其實不好睡</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間乾淨 床大 </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>]

# %%
# 飯店整體的評分
soup.find_all("div",{"id":"review_list_score"})
# Out:
# [<div class="" id="review_list_score">
#  <span class=" review_list_score_breakdown_right">
#  <ul class="review_score_breakdown_list list_tighten clearfix" id="review_list_score_breakdown">
#  <li class="clearfix one_col" data-question="hotel_clean">
#  <p class="review_score_name">整潔度</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="80" style="width: 80%;"></div>
#  </div>
#  <p class="review_score_value">8</p>
#  </li>
#  <li class="clearfix one_col" data-question="hotel_comfort">
#  <p class="review_score_name">舒適程度</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="77" style="width: 77%;"></div>
#  </div>
#  <p class="review_score_value">7.7</p>
#  </li>
#  <li class="clearfix one_col" data-question="hotel_services">
#  <p class="review_score_name">設施</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="76" style="width: 76%;"></div>
#  </div>
#  <p class="review_score_value">7.6</p>
#  </li>
#  <li class="clearfix one_col" data-question="hotel_staff">
#  <p class="review_score_name">員工素質</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="79" style="width: 79%;"></div>
#  </div>
#  <p class="review_score_value">7.9</p>
#  </li>
#  <li class="clearfix one_col" data-question="hotel_value">
#  <p class="review_score_name">性價比</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="73" style="width: 73%;"></div>
#  </div>
#  <p class="review_score_value">7.3</p>
#  </li>
#  <li class="clearfix one_col" data-question="hotel_wifi">
#  <p class="review_score_name">免費 WiFi</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="75" style="width: 75%;"></div>
#  </div>
#  <p class="review_score_value">7.5</p>
#  </li>
#  <li class="clearfix one_col" data-question="hotel_location">
#  <p class="review_score_name">住宿地點</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="89" style="width: 89%;"></div>
#  </div>
#  <p class="review_score_value">8.9</p>
#  </li>
#  </ul>
#  </span>
#  </div>,
#  <div class=" review_list_score_container lang_ltr scores_full_layout" id="review_list_score">
#  <div class="reviews_panel_header_score">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__inline review-score-widget__20 ">
#  <span aria-label="分數7.9分" class="review-score-badge" role="link">
#  7.9
#  </span>
#  <span aria-label="評比好" class="review-score-widget__text" role="link">
#  好
#  </span>
#  <span aria-label="這是 8,215 則住客評語給予的平均分數" class="review-score-widget__subtext" role="link">
#  8,215 則評語
#  </span>
#  </span>
#  <span aria-hidden="true" class="reviews_panel_header_score--arrow js-fly-content-tooltip" data-content-tooltip-element="#tooltip_score_distribution" data-et-mouseenter="customGoal:adUAVGZaeaRMSAdJFYJO:1" data-extra-class-tooltip="fly-content-tooltip fly-content-tooltip--review-distribution" data-require-tooltip-class="js-fly-content-tooltip">
#  <svg class="bk-icon -fonticon-triangledown" height="5" viewbox="0 0 65 32" width="12">
#  <path d="M0 0l32.32 32L64.64 0z"></path>
#  </svg>
#  </span>
#  </div>
#  <div id="tooltip_score_distribution" style="display:none">
#  <div class="review_list_block one_col">
#  <div class="scores_full_layout">
#  <ul class="review_score_breakdown_list list_tighten clearfix" id="review_list_score_distribution">
#  <li class="clearfix" data-question="review_adj_superb">
#  <p class="review_score_name">
#  好極了: 9+
#  </p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="30" style="width: 30%;"></div>
#  </div>
#  <p class="review_score_value">2437</p>
#  </li>
#  <li class="clearfix" data-question="review_adj_good">
#  <p class="review_score_name">
#  好: 7 – 9
#  </p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="48" style="width: 48%;"></div>
#  </div>
#  <p class="review_score_value">3947</p>
#  </li>
#  <li class="clearfix" data-question="review_adj_average_okay">
#  <p class="review_score_name">
#  可以: 5 – 7
#  </p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="18" style="width: 18%;"></div>
#  </div>
#  <p class="review_score_value">1447</p>
#  </li>
#  <li class="clearfix" data-question="review_adj_poor">
#  <p class="review_score_name">
#  差勁: 3 – 5
#  </p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="4" style="width: 4%;"></div>
#  </div>
#  <p class="review_score_value">310</p>
#  </li>
#  <li class="clearfix" data-question="review_adj_very_poor">
#  <p class="review_score_name">
#  非常差: 1 – 3
#  </p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="1" style="width: 1%;"></div>
#  </div>
#  <p class="review_score_value">73</p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div id="review_list_score_breakdown">
#  <div class="review_list_score_breakdown_left">
#  <ul class="review_score_breakdown_list list_tighten clearfix">
#  <li class="clearfix" data-question="hotel_clean">
#  <p class="review_score_name">整潔度</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="80" style="width: 80%;"></div>
#  </div>
#  <p class="review_score_value">8</p>
#  </li>
#  <li class="clearfix" data-question="hotel_comfort">
#  <p class="review_score_name">舒適程度</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="77" style="width: 77%;"></div>
#  </div>
#  <p class="review_score_value">7.7</p>
#  </li>
#  <li class="clearfix" data-question="hotel_services">
#  <p class="review_score_name">設施</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="76" style="width: 76%;"></div>
#  </div>
#  <p class="review_score_value">7.6</p>
#  </li>
#  <li class="clearfix" data-question="hotel_staff">
#  <p class="review_score_name">員工素質</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="79" style="width: 79%;"></div>
#  </div>
#  <p class="review_score_value">7.9</p>
#  </li>
#  </ul>
#  </div>
#  <div class="review_list_score_breakdown_right">
#  <ul class="review_score_breakdown_list list_tighten clearfix">
#  <li class="clearfix" data-question="hotel_value">
#  <p class="review_score_name">性價比</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="73" style="width: 73%;"></div>
#  </div>
#  <p class="review_score_value">7.3</p>
#  </li>
#  <li class="clearfix" data-question="hotel_wifi">
#  <p class="review_score_name">免費 WiFi</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="75" style="width: 75%;"></div>
#  </div>
#  <p class="review_score_value">7.5</p>
#  </li>
#  <li class="clearfix" data-question="hotel_location">
#  <p class="review_score_name">住宿地點</p>
#  <div class="score_bar">
#  <div class="score_bar_value" data-score="89" style="width: 89%;"></div>
#  </div>
#  <p class="review_score_value">8.9</p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>]

# %%
for string in soup.find_all("div",{"id":"review_list_score"}):
    #print(string.get_text("\n",strip=True))
    print(string.get_text(strip=True),"\n")
# Out:
# 整潔度8舒適程度7.7設施7.6員工素質7.9性價比7.3免費 WiFi7.5住宿地點8.9
#
# 7.9好8,215 則評語好極了: 9+2437好: 7 – 93947可以: 5 – 71447差勁: 3 – 5310非常差: 1 – 373整潔度8舒適程度7.7設施7.6員工素質7.9性價比7.3免費 WiFi7.5住宿地點8.9

# %%
#第一頁有幾位留言者之個別評分 不太有用!
soup.find_all('div',{'class':'review_item_header_score_container'})
# Out:
# [<div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數7.9分" class="review-score-badge" role="link">
#  7.9
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__pleasant review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數6.3分" class="review-score-badge" role="link">
#  6.3
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__average_okay review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數5.8分" class="review-score-badge" role="link">
#  5.8
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__pleasant review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數6.3分" class="review-score-badge" role="link">
#  6.3
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__fabulous review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數8.8分" class="review-score-badge" role="link">
#  8.8
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__exceptional review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數10分" class="review-score-badge" role="link">
#  10
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數7.9分" class="review-score-badge" role="link">
#  7.9
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數7.5分" class="review-score-badge" role="link">
#  7.5
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數7.1分" class="review-score-badge" role="link">
#  7.1
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__superb review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數9.2分" class="review-score-badge" role="link">
#  9.2
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__exceptional review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數10分" class="review-score-badge" role="link">
#  10
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__exceptional review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數10分" class="review-score-badge" role="link">
#  10
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__very_good review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數8.3分" class="review-score-badge" role="link">
#  8.3
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__average_passable review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數5.4分" class="review-score-badge" role="link">
#  5.4
#  </span>
#  </span>
#  </div>, <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__very_good review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數8.3分" class="review-score-badge" role="link">
#  8.3
#  </span>
#  </span>
#  </div>]

# %%
#第一頁有幾位留言者之個別評分 
hotel_score = soup.find_all('div',{'class':'review_item_header_score_container'})
for p in hotel_score:
    print(p.span.text.strip())
# Out:
# 7.9
# 6.3
# 5.8
# 6.3
# 8.8
# 10
# 7.9
# 7.5
# 7.1
# 9.2
# 10
# 10
# 8.3
# 5.4
# 8.3

# %%
#留言者姓名

hotel_lodger_name = soup.find_all('div',{'class':'review_item_reviewer' } ) 
for p in hotel_lodger_name:
    print(p.h4.text.strip())  #姓名為h4標籤   text部分只列印文字姓名 strip去頭尾空
# Out:
# 匿名
# 匿名
# Jessica
# Kobert
# 蕭先森
# 正風
# Kwaihong
# 剛剛
# Lai
# Siu
# 政杰
# Alick
# Jessie
# 匿名
# 匿名

# %%
hotel_lodger_name = soup.find_all('div',{'class':'review_item_reviewer' } ) 
for p in hotel_lodger_name:
    print(p.h4.text.strip())  #姓名為h4標籤   text部分只列印文字姓名 strip去頭尾空白
# Out:
# 匿名
# 匿名
# Jessica
# Kobert
# 蕭先森
# 正風
# Kwaihong
# 剛剛
# Lai
# Siu
# 政杰
# Alick
# Jessie
# 匿名
# 匿名

# %%
for news in soup.select('.review_item_reviewer'):
#找出所有 class:review_pos  的CSS
    #print(news)
    if(len(news.select('h4'))>0   ):
        print(news.select('h4')[0].text.strip())
        #h2 = (news.select('h4')[0].text.strip())
# Out:
# 匿名
# 匿名
# Jessica
# Kobert
# 蕭先森
# 正風
# Kwaihong
# 剛剛
# Lai
# Siu
# 政杰
# Alick
# Jessie
# 匿名
# 匿名

# %%
soup.select('.review_item_review_content')
# Out:
# [<div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點方便，衞生</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音差，正巧遇到地震，但飯店廣播系統反應太慢。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通方便</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點超方便!</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晚上水渠常常發出水聲，及其他雜聲…</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通便利</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>服務人員可能因忙碌忽略微笑關係，表情比較嚴肅。另房間桌燈座下方電線蓋子未蓋妥。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間及浴室都很乾淨，住宿地點很便利！早餐多元化，非常美味！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>浴室門口記得做止水條,不然水會流出來哦</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>早餐豐富,不錯</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晩上聽到別的房間人搬東西的東西！太嘈！隔音不是很好！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>地氈有污積。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點非常近西門捷運站，入住及退房不同樓層，方便辦理入住及退房。並提供到足夠空間寄存行李。</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音設備好差！ 好嘈！</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>Location </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>食物一般，款式太少</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>沒有</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>物超所值，隔音也不錯，強烈推薦</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>空調無法調自己想要的溫度，調完後還是會回到19度，很冷</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>空間舒適</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>沒有免費的停車場</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點佳，價錢適中
#  房間雖然不是很大，但還算舒適
#  員工有貼心備註並提供需求</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音非常差每次有人經過房間都聽到對話或附近出入的開關房門聲非常嘈吵完全影響睡眠空調亦不準確與預設的溫度差距10幾度房務員亦非常粗魯製造大量噪音</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>職員給予要求的高樓層</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>有對外窗戶但沒有遮光窗簾 霓虹燈亮 怕光的人其實不好睡</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間乾淨 床大 </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>]

# %%
soup.findAll('div',{'class':'review_item_review_content'})[0]
# Out:
# <div class="review_item_review_content">
# <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點方便，衞生</p>
# <p class="review_staydate ">
# 2018 年 3 月入住：
# </p>
# </div>

# %%
soup.findAll('div',{'class':'review_item_review_content'})[0].findAll('p',{'class':'review_neg'})
# Out:
# []

# %%
soup.findAll('div',{'class':'review_item_review_content'})[0].findAll('p',{'class':'review_pos'})
# Out:
# [<p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點方便，衞生</p>]

# %%
soup.findAll('div',{'class':'review_item_review_content'})[0].findAll('p',{'class':'review_pos'})[0].get_text()
# Out:
# '눇地點方便，衞生'

# %%
for reviews in soup.findAll('div',{'class':'review_item_review_content'}):
    for review in reviews.findAll('p',{'class':'review_pos'}):
        print(review.get_text())
# Out:
# 눇地點方便，衞生
# 눇交通方便
# 눇地點超方便!
# 눇交通便利
# 눇房間及浴室都很乾淨，住宿地點很便利！早餐多元化，非常美味！
# 눇早餐豐富,不錯
# 눇地點非常近西門捷運站，入住及退房不同樓層，方便辦理入住及退房。並提供到足夠空間寄存行李。
# 눇Location
# 눇沒有
# 눇物超所值，隔音也不錯，強烈推薦
# 눇空間舒適
# 눇地點佳，價錢適中
# 房間雖然不是很大，但還算舒適
# 員工有貼心備註並提供需求
# 눇職員給予要求的高樓層
# 눇房間乾淨 床大

# %%
for reviews in soup.findAll('div',{'class':'review_item_review_content'}):
    for review in reviews.findAll('p',{'class':'review_neg'}):
        print(review.get_text())
# Out:
# 눉隔音差，正巧遇到地震，但飯店廣播系統反應太慢。
# 눉晚上水渠常常發出水聲，及其他雜聲…
# 눉服務人員可能因忙碌忽略微笑關係，表情比較嚴肅。另房間桌燈座下方電線蓋子未蓋妥。
# 눉浴室門口記得做止水條,不然水會流出來哦
# 눉晩上聽到別的房間人搬東西的東西！太嘈！隔音不是很好！
# 눉地氈有污積。
# 눉隔音設備好差！ 好嘈！
# 눉食物一般，款式太少
# 눉空調無法調自己想要的溫度，調完後還是會回到19度，很冷
# 눉沒有免費的停車場
# 눉隔音非常差每次有人經過房間都聽到對話或附近出入的開關房門聲非常嘈吵完全影響睡眠空調亦不準確與預設的溫度差距10幾度房務員亦非常粗魯製造大量噪音
# 눉有對外窗戶但沒有遮光窗簾 霓虹燈亮 怕光的人其實不好睡

# %%
soup.select('.review_item_review')
# Out:
# [<div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數7.9分" class="review-score-badge" role="link">
#  7.9
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content" href="/reviews/tw/hotel/richardson/review/f5ddbbb1c3c157f1.zh-tw.html">
#  好
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 有幼童同行的家庭
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 中城套房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住 3 晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點方便，衞生</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__pleasant review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數6.3分" class="review-score-badge" role="link">
#  6.3
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content" href="/reviews/tw/hotel/richardson/review/ecb95827c3ad258d.zh-tw.html">
#  令人愉悅
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 有幼童同行的家庭
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 高級家庭間
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音差，正巧遇到地震，但飯店廣播系統反應太慢。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通方便</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__average_okay review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數5.8分" class="review-score-badge" role="link">
#  5.8
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content" href="/reviews/tw/hotel/richardson/review/1c9b11d6c06399e3.zh-tw.html">
#  可以
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 夫婦/情侶
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 標準市景雙人間
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住 4 晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點超方便!</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__pleasant review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數6.3分" class="review-score-badge" role="link">
#  6.3
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content recent_property_review_title" href="/reviews/tw/hotel/richardson/review/5767a3122ebdfe37.zh-tw.html">
#  「交通便利，地方整潔，但早餐一般。」
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 夫婦/情侶
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 豪華雙床房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住 3 晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晚上水渠常常發出水聲，及其他雜聲…</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通便利</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__fabulous review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數8.8分" class="review-score-badge" role="link">
#  8.8
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content" href="/reviews/tw/hotel/richardson/review/70e0eacb0d2945a6.zh-tw.html">
#  很棒
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 夫婦/情侶
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 中城套房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>服務人員可能因忙碌忽略微笑關係，表情比較嚴肅。另房間桌燈座下方電線蓋子未蓋妥。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間及浴室都很乾淨，住宿地點很便利！早餐多元化，非常美味！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__exceptional review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數10分" class="review-score-badge" role="link">
#  10
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content high_score_word" href="/reviews/tw/hotel/richardson/review/3213da15e81d0185.zh-tw.html">
#  傑出
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 朋友團體
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 豪華家庭房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>浴室門口記得做止水條,不然水會流出來哦</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>早餐豐富,不錯</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數7.9分" class="review-score-badge" role="link">
#  7.9
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content" href="/reviews/tw/hotel/richardson/review/36971e782daa9366.zh-tw.html">
#  好
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 夫婦/情侶
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 標準市景雙人間
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晩上聽到別的房間人搬東西的東西！太嘈！隔音不是很好！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數7.5分" class="review-score-badge" role="link">
#  7.5
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content recent_property_review_title" href="/reviews/tw/hotel/richardson/review/3c1b2a3708d03b87.zh-tw.html">
#  「交通方便，整體非常滿意。個人評分75分，若能改善地氈清潔程度，評分可達80分。下次也能作為首選入住的酒店」
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 夫婦/情侶
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 豪華雙人房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住 2 晚
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>地氈有污積。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點非常近西門捷運站，入住及退房不同樓層，方便辦理入住及退房。並提供到足夠空間寄存行李。</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__good review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數7.1分" class="review-score-badge" role="link">
#  7.1
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content recent_property_review_title" href="/reviews/tw/hotel/richardson/review/006c198c3a833dac.zh-tw.html">
#  「早餐質素麻麻， 可以不吃！ 座位安排混亂 ！另房間太冷， 不可調教！」
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 有幼童同行的家庭
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 豪華家庭房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住 2 晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音設備好差！ 好嘈！</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>Location </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__superb review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數9.2分" class="review-score-badge" role="link">
#  9.2
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content" href="/reviews/tw/hotel/richardson/review/a4e02b2030eb3de2.zh-tw.html">
#  好極了
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 有幼童同行的家庭
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 豪華家庭房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住 5 晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>食物一般，款式太少</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>沒有</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__exceptional review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數10分" class="review-score-badge" role="link">
#  10
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content high_score_word" href="/reviews/tw/hotel/richardson/review/9dcbc3080dc1d396.zh-tw.html">
#  傑出
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 朋友團體
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 標準市景雙人間
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>物超所值，隔音也不錯，強烈推薦</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__exceptional review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數10分" class="review-score-badge" role="link">
#  10
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content high_score_word" href="/reviews/tw/hotel/richardson/review/d547168e819ff0fc.zh-tw.html">
#  傑出
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 商務行程
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 獨行旅客
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 高級家庭間
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>空調無法調自己想要的溫度，調完後還是會回到19度，很冷</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>空間舒適</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__very_good review-score-widget__score-only review-score-widget__no-subtext ">
#  <span aria-label="分數8.3分" class="review-score-badge" role="link">
#  8.3
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content" href="/reviews/tw/hotel/richardson/review/85eb91d3f3290185.zh-tw.html">
#  非常好
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 有幼童同行的家庭
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 豪華家庭房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>沒有免費的停車場</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點佳，價錢適中
#  房間雖然不是很大，但還算舒適
#  員工有貼心備註並提供需求</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__average_passable review-score-widget__low review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數5.4分" class="review-score-badge" role="link">
#  5.4
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content recent_property_review_title" href="/reviews/tw/hotel/richardson/review/3a76bf3679ac59ab.zh-tw.html">
#  「非常不舒適的住宿經驗」
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 獨行旅客
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 精緻雙人間（無窗）
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住 4 晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音非常差每次有人經過房間都聽到對話或附近出入的開關房門聲非常嘈吵完全影響睡眠空調亦不準確與預設的溫度差距10幾度房務員亦非常粗魯製造大量噪音</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>職員給予要求的高樓層</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>, <div class="review_item_review">
#  <div class="review_item_review_container lang_ltr recent_property_reviews_item">
#  <div class="review_item_review_header">
#  <div class=" review_item_header_score_container ">
#  <span class=" review-score-widget review-score-widget__very_good review-score-widget__score-only review-score-widget__no-subtext jq_tooltip ">
#  <span aria-label="分數8.3分" class="review-score-badge" role="link">
#  8.3
#  </span>
#  </span>
#  </div>
#  <div class="review_item_header_content_container">
#  <a class="review_item_header_content recent_property_review_title" href="/reviews/tw/hotel/richardson/review/66d94e3c64b1296d.zh-tw.html">
#  「離西門站近的良好住宿點」
#  </a>
#  </div>
#  </div>
#  <ul class="review_item_info_tags">
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 休閒觀光
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 有幼童同行的家庭
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 豪華家庭房
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 入住了1晚
#  </li>
#  <li class="review_info_tag ">
#  <span class="bullet">•</span> 自手機送出
#  </li>
#  </ul>
#  <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>有對外窗戶但沒有遮光窗簾 霓虹燈亮 怕光的人其實不好睡</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間乾淨 床大 </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>
#  </div>
#  </div>]

# %%
soup.select('.review_item_review_content')
# Out:
# [<div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點方便，衞生</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音差，正巧遇到地震，但飯店廣播系統反應太慢。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通方便</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點超方便!</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晚上水渠常常發出水聲，及其他雜聲…</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>交通便利</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>服務人員可能因忙碌忽略微笑關係，表情比較嚴肅。另房間桌燈座下方電線蓋子未蓋妥。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間及浴室都很乾淨，住宿地點很便利！早餐多元化，非常美味！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>浴室門口記得做止水條,不然水會流出來哦</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>早餐豐富,不錯</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>晩上聽到別的房間人搬東西的東西！太嘈！隔音不是很好！</p>
#  <p class="review_staydate ">
#  2018 年 3 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>地氈有污積。</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點非常近西門捷運站，入住及退房不同樓層，方便辦理入住及退房。並提供到足夠空間寄存行李。</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音設備好差！ 好嘈！</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>Location </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>食物一般，款式太少</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>沒有</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>物超所值，隔音也不錯，強烈推薦</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>空調無法調自己想要的溫度，調完後還是會回到19度，很冷</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>空間舒適</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>沒有免費的停車場</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>地點佳，價錢適中
#  房間雖然不是很大，但還算舒適
#  員工有貼心備註並提供需求</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>隔音非常差每次有人經過房間都聽到對話或附近出入的開關房門聲非常嘈吵完全影響睡眠空調亦不準確與預設的溫度差距10幾度房務員亦非常粗魯製造大量噪音</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>職員給予要求的高樓層</p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>, <div class="review_item_review_content">
#  <p class="review_neg"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:1">눉</i>有對外窗戶但沒有遮光窗簾 霓虹燈亮 怕光的人其實不好睡</p><p class="review_pos"><i class="review_item_icon" data-et-click="customGoal:HDDHQDSJPXaFWDaXe:2">눇</i>房間乾淨 床大 </p>
#  <p class="review_staydate ">
#  2018 年 2 月入住：
#  </p>
#  </div>]

# %%
for review in soup.select('.review_item_review_content'):        
    if(review.select('.review_neg')):
        print ("-:",review.select('.review_neg')[0].text)
    if (review.select('.review_pos')):
        print ("+:",review.select('.review_pos')[0].text)
# Out:
# +: 눇地點方便，衞生
# -: 눉隔音差，正巧遇到地震，但飯店廣播系統反應太慢。
# +: 눇交通方便
# +: 눇地點超方便!
# -: 눉晚上水渠常常發出水聲，及其他雜聲…
# +: 눇交通便利
# -: 눉服務人員可能因忙碌忽略微笑關係，表情比較嚴肅。另房間桌燈座下方電線蓋子未蓋妥。
# +: 눇房間及浴室都很乾淨，住宿地點很便利！早餐多元化，非常美味！
# -: 눉浴室門口記得做止水條,不然水會流出來哦
# +: 눇早餐豐富,不錯
# -: 눉晩上聽到別的房間人搬東西的東西！太嘈！隔音不是很好！
# -: 눉地氈有污積。
# +: 눇地點非常近西門捷運站，入住及退房不同樓層，方便辦理入住及退房。並提供到足夠空間寄存行李。
# -: 눉隔音設備好差！ 好嘈！
# +: 눇Location
# -: 눉食物一般，款式太少
# +: 눇沒有
# +: 눇物超所值，隔音也不錯，強烈推薦
# -: 눉空調無法調自己想要的溫度，調完後還是會回到19度，很冷
# +: 눇空間舒適
# -: 눉沒有免費的停車場
# +: 눇地點佳，價錢適中
# 房間雖然不是很大，但還算舒適
# 員工有貼心備註並提供需求
# -: 눉隔音非常差每次有人經過房間都聽到對話或附近出入的開關房門聲非常嘈吵完全影響睡眠空調亦不準確與預設的溫度差距10幾度房務員亦非常粗魯製造大量噪音
# +: 눇職員給予要求的高樓層
# -: 눉有對外窗戶但沒有遮光窗簾 霓虹燈亮 怕光的人其實不好睡
# +: 눇房間乾淨 床大

# %%
for review in soup.select('.review_item_review_content'):        
    if(review.select('.review_neg')):
        re = review.select('.review_neg')
        print ("-:", re[0].i.next_sibling)
        #print ("-:",review.select('.review_neg')[0].text)
    if (review.select('.review_pos')):
        #print ("+:",review.select('.review_pos')[0].text)
        print ("+:",review.select('.review_pos')[0].i.next_sibling)
# Out:
# +: 地點方便，衞生
# -: 隔音差，正巧遇到地震，但飯店廣播系統反應太慢。
# +: 交通方便
# +: 地點超方便!
# -: 晚上水渠常常發出水聲，及其他雜聲…
# +: 交通便利
# -: 服務人員可能因忙碌忽略微笑關係，表情比較嚴肅。另房間桌燈座下方電線蓋子未蓋妥。
# +: 房間及浴室都很乾淨，住宿地點很便利！早餐多元化，非常美味！
# -: 浴室門口記得做止水條,不然水會流出來哦
# +: 早餐豐富,不錯
# -: 晩上聽到別的房間人搬東西的東西！太嘈！隔音不是很好！
# -: 地氈有污積。
# +: 地點非常近西門捷運站，入住及退房不同樓層，方便辦理入住及退房。並提供到足夠空間寄存行李。
# -: 隔音設備好差！ 好嘈！
# +: Location
# -: 食物一般，款式太少
# +: 沒有
# +: 物超所值，隔音也不錯，強烈推薦
# -: 空調無法調自己想要的溫度，調完後還是會回到19度，很冷
# +: 空間舒適
# -: 沒有免費的停車場
# +: 地點佳，價錢適中
# 房間雖然不是很大，但還算舒適
# 員工有貼心備註並提供需求
# -: 隔音非常差每次有人經過房間都聽到對話或附近出入的開關房門聲非常嘈吵完全影響睡眠空調亦不準確與預設的溫度差距10幾度房務員亦非常粗魯製造大量噪音
# +: 職員給予要求的高樓層
# -: 有對外窗戶但沒有遮光窗簾 霓虹燈亮 怕光的人其實不好睡
# +: 房間乾淨 床大

# %%
# !conda config --add channels conda-forge
# !conda install selenium
# Out:
# Warning: 'conda-forge' already in 'channels' list, moving to the front
# Using Anaconda API: https://api.anaconda.org
# Fetching package metadata .............
# Solving package specifications: ..........
#
# # All requested packages already installed.
# # packages in environment at /opt/conda:
# #
# selenium                  3.9.0                    py35_0    conda-forge

# %% [raw]
# 如何使用 Selenium 以及 Python 輕鬆抓取 Agoda 的旅館資訊?
#
# https://www.youtube.com/watch?v=MQH4Rau_F_A

# %% [raw]
# # chrome driver如何使用請參考:
# http://jialin128.pixnet.net/blog/post/114056630-%5Bpython%5D--%E4%BD%BF%E7%94%A8selenium%E5%9C%A8google-chrome%E7%80%8F%E8%A6%BD%E5%99%A8

# %% [raw]
# http://www.booking.com/hotel/tw/richardson.zh-tw.html?aid=304142;label=gen173nr-1FEghlcnJvcjQwNCiCAkICWFhIM2IFbm9yZWZo5wGIAQGYATC4AQbIAQzYAQHoAQH4AQuoAgM;sid=90b9c00bb8c3b7852742d43f6165a9c4;dcid=12;checkin=2016-03-28;checkout=2016-03-29;dest_id=-2637882;dest_type=city;highlighted_blocks=132412401_85683812_0_0;room1=A%2CA;sb_price_type=total;srfid=e4cc12616d37bc46a3986294c48e495e1250c468X1;type=total;ucfs=1&;lang=zh-tw#tab-reviews

# %% [raw]
# https://www.booking.com/reviewlist.zh-tw.html?aid=304142;label=gen173nr-1FEghlcnJvcjQwNCiCAkICWFhIM2IFbm9yZWZo5wGIAQGYATC4AQbIAQzYAQHoAQH4AQuoAgM;sid=5359d7edc03f473e1747b8b55f54f8fb;cc1=tw;dist=1;pagename=richardson;r_lang=zh;roomtype=-1;type=total&;offset=20;rows=10&_=1516903624235

# %%
# 這是從F12 Network XHR Header中 得到的 網址
web = "https://www.booking.com/reviewlist.zh-tw.html?aid=304142;label=gen173nr-1FEghlcnJvcjQwNCiCAkICWFhIM2IFbm9yZWZo5wGIAQGYATC4AQbIAQzYAQHoAQH4AQuoAgM;sid=5359d7edc03f473e1747b8b55f54f8fb;cc1=tw;dist=1;pagename=richardson;r_lang=zh;roomtype=-1;type=total&;offset=20;rows=10&_=1516903624235"

# %%
# 這是從selenium IDE中 按下下一頁按鈕 得到的 網址
web = "https://www.booking.com/reviewlist.zh-tw.html?aid=304142;label=gen173nr-1FEghlcnJvcjQwNCiCAkICWFhIM2IFbm9yZWZo5wGIAQGYATC4AQbIAQzYAQHoAQH4AQuoAgM;sid=5359d7edc03f473e1747b8b55f54f8fb;cc1=tw;dist=1;pagename=richardson;r_lang=zh;roomtype=-1;type=total&;offset=0;rows=10"

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
#browser = webdriver.Firefox(executable_path=r'./geckodriver.exe')
chrome_path = "./chromedriver.exe" #chromedriver.exe執行檔所存在的路徑
browser = webdriver.Chrome(chrome_path)
browser.get(web)
soup = BeautifulSoup(browser.page_source,"lxml")
count=0
limit_page=1
while len(soup.select('.page_link.review_next_page'))>0:
    for review in soup.select('.review_item_review'):        
        if(review.select('.review_neg')):
            print ("-:",review.select('.review_neg')[0].i.next_sibling)
        if (review.select('.review_pos')):
            print ("+:",review.select('.review_pos')[0].i.next_sibling)
    '''
    for reviews in soup.findAll('div',{'class':'review_item_review_content'}):
        for review in reviews.findAll('p',{'class':'review_pos'}):
            print('pos:',review.get_text())
    for reviews in soup.findAll('div',{'class':'review_item_review_content'}):
        for review in reviews.findAll('p',{'class':'review_neg'}):
            print('neg:',review.get_text())
    '''
    #for ele in soup.select('.review_item_review p'):
    #    print (ele.text[1:])
    browser.find_element_by_id("review_next_page_link").click()    
    soup = BeautifulSoup(browser.page_source,"lxml")
    print(count,'--------------------------')
    count=count+1
    if (count >= limit_page):
        break
    time.sleep(5)    
browser.close()
# Out:
# +: 交通非常方便，這次訂了間豪華家庭，裡面包了早餐，非常不錯。酒店餐廳的自助餐很多東西吃，給個讚！櫃檯前的服務人員和房務員都非常有禮貌，服務水平良好。
# -: 櫃檯接電話口氣感覺不怎麼好
# +: 環境舒服
# -: 冷氣太大，調整不到！最後要關掉才行！
# -: 电梯到房间距离老远，没有自助洗衣，屋内挂衣服地方太少
# +: 车站近，位置好，购物超方便
# -: 设施比较老旧，隔音较差。
# +: 离西门町大概5分钟步行路程，隔壁就是中山堂，也正对着西门站5号出口。
# -: 房間有點小
#
# +: 地點方便
# -: 因为房间没有窗户，灰尘很大鼻子一直不通气
# +: 装修很有个性，地理位置很好，很方便
# -: 床不是很舒服
# +: 位置非常好。门口就是地铁，5号口出来，西门站
# -: 第一天被單有味道，早餐不好吃，房間衣架只有三個！大堂有家火鍋店，晚上回去一進電梯滿滿的味道！
# +: 交通便利，房間舒適
# -: 隔音效果差
#
# +: 酒店设施比较新
# -: 櫃檯接電話口氣感覺不怎麼好
# -: 不會再住
# +: 沒有
# -: 房間細住在15樓不停聽到有水管的聲音， 換了一次房間也是換到15樓， 因為在這裏網上訂購的房間全部都在這層， 所以換房間沒有分別 ，晚上也是這樣， 整晚也聽到有水管的聲音 ， 幾天睡覺也不好， 有一天晚上沒有水沖涼， 職員說緊急維修中，整晚也没有水。
# +: 基本上沒有滿意的地方
# +: 環境舒服
# -: 冷氣太大，調整不到！最後要關掉才行！
# +: 满意
# -: 住宿期間停水。當時正在洗澡滿身肥皂，只好致電服務台了解。自稱Albert職員接聽電話，通知可能因水局挖馬路導致水管爆裂，引致酒店停水。告訴他我當時狼狽情況希望提供協助。他非常之不耐煩叫我用毛巾自行擦淨處理，當我表示那不是最好方法。話未說完，他就說水管不時他挖斷，問我要他怎樣？就把我電話掛斷！
# -: 員工態度差，突然無水但又無交代，打電話去櫃檯問，只答「我們都不知何時有水！！」
# 地下公用洗手間員工態度超差，我只想把女洗手間的大門關上，因男洗手間太近，好像被望著整理衣服不太方便，清潔女工竟用很兇的語氣叫我不要關門，我說了因不太好看才關上，她便大大聲說「門是不能關上，不好看也沒辦法！」我再說不太好看，關一會便會開，但她再次說「不能關！！」我也不明白為什麼，因那時只有我一個人在！
# 整體而言，員工態度愛理不理。這次入住不開心
# -: 电梯到房间距离老远，没有自助洗衣，屋内挂衣服地方太少
# +: 车站近，位置好，购物超方便
# -: 设施比较老旧，隔音较差。
# +: 离西门町大概5分钟步行路程，隔壁就是中山堂，也正对着西门站5号出口。
# -: 房間有點小
#
# +: 地點方便
# -: 因为房间没有窗户，灰尘很大鼻子一直不通气
# +: 装修很有个性，地理位置很好，很方便
# -: 床不是很舒服
# +: 位置非常好。门口就是地铁，5号口出来，西门站
# -: 房內設計不太方便用家。
# +: 地點方便，位置佳。
# -: 没有的哦。
# +: 非常不错。
# 0 --------------------------
